# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_Facebook.csv')

# %%
print(df.columns)
# Out:
# Index(['Page_total_likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
print(df.shape)
# Out:
# (500, 19)

# %%
index = df.index
columns = df.columns
values = df.values

# %%
index
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
columns
# Out:
# Index(['Page_total_likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
values
# Out:
# array([[139441, 'Photo', 2, ..., 79.0, 17.0, 100],
#        [139441, 'Status', 2, ..., 130.0, 29.0, 164],
#        [139441, 'Photo', 3, ..., 66.0, 14.0, 80],
#        ...,
#        [81370, 'Photo', 1, ..., 93.0, 18.0, 115],
#        [81370, 'Photo', 3, ..., 91.0, 38.0, 136],
#        [81370, 'Photo', 2, ..., 91.0, 28.0, 119]], dtype=object)

# %%
df['Type']
# Out:
# 0       Photo
# 1      Status
# 2       Photo
# 3       Photo
# 4       Photo
# 5      Status
# 6       Photo
# 7       Photo
# 8      Status
# 9       Photo
# 10     Status
# 11      Photo
# 12      Photo
# 13      Photo
# 14      Photo
# 15     Status
# 16      Photo
# 17      Photo
# 18     Status
# 19      Photo
# 20      Photo
# 21      Photo
# 22       Link
# 23      Photo
# 24     Status
# 25     Status
# 26     Status
# 27      Photo
# 28      Photo
# 29      Video
#         ...
# 470      Link
# 471     Photo
# 472     Photo
# 473     Photo
# 474     Photo
# 475     Photo
# 476     Photo
# 477      Link
# 478     Photo
# 479     Photo
# 480     Photo
# 481      Link
# 482     Photo
# 483     Photo
# 484     Photo
# 485      Link
# 486     Photo
# 487     Photo
# 488     Photo
# 489     Photo
# 490     Photo
# 491     Photo
# 492      Link
# 493     Photo
# 494     Photo
# 495     Photo
# 496     Photo
# 497     Photo
# 498     Photo
# 499     Photo
# ...

# %% [markdown]
# Subsetting -

# %%
subset_df = df[['Type','like']]
subset_df
# Out:
#        Type    like
# 0     Photo    79.0
# 1    Status   130.0
# 2     Photo    66.0
# 3     Photo  1572.0
# 4     Photo   325.0
# 5    Status   152.0
# 6     Photo   249.0
# 7     Photo   325.0
# 8    Status   161.0
# 9     Photo   113.0
# 10   Status   233.0
# 11    Photo    88.0
# 12    Photo    90.0
# 13    Photo   137.0
# 14    Photo   577.0
# 15   Status    86.0
# 16    Photo    40.0
# 17    Photo   678.0
# 18   Status    54.0
# 19    Photo    34.0
# 20    Photo    66.0
# 21    Photo     0.0
# 22     Link    16.0
# 23    Photo    72.0
# 24   Status    99.0
# 25   Status    88.0
# 26   Status   412.0
# 27    Photo   100.0
# 28    Photo   523.0
# 29    Video   143.0
# ..      ...     ...
# 470    Link   114.0
# 471   Photo   160.0
# 472   Photo    46.0
# 473   Photo   136.0
# 474   Photo    73.0
# 475   Photo    65.0
# 476   Photo   579.0
# 477    Link   101.0
# 478   Photo    74.0
# 479   Photo    84.0
# 480   Photo   360.0
# 481    Link     5.0
# 482   Photo   187.0
# ...

# %%
df[0:2]
# Out:
#    Page_total_likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# 1                    1457                     1361
#
#    Lifetime Post Consumptions  \
# 0                         159
# 1                        1674
#
#    Lifetime Post Impressions by people who have liked your Page  \
# 0                                               3078
# 1                                              11710
#
#    Lifetime Post reach by people who like your Page  \
# ...

# %%
dff =df[df.share>140]
dff
# Out:
#      Page_total_likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441  Photo         2          12             2         10
# 168            135428  Photo         1           9             3         10
# 244            130791  Photo         2           7             3          5
# 460             92507  Photo         3           2             1         13
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 3     1.0                      50128                            87991
# 168   0.0                      41984                            68290
# 244   1.0                     180480                           319133
# 460   0.0                      55520                           665792
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 3                      2211                      790
# 168                    3370                     2420
# 244                    8072                     4010
# ...

# %% [markdown]
# Merging -

# %%
subset1_df = df[['Type','like']]
subset2_df = df[['Type','share']]
result = pd.merge(subset1_df, subset2_df, on='Type') 
result
# Out:
#          Type   like  share
# 0       Photo   79.0   17.0
# 1       Photo   79.0   14.0
# 2       Photo   79.0  147.0
# 3       Photo   79.0   49.0
# 4       Photo   79.0   27.0
# 5       Photo   79.0   14.0
# 6       Photo   79.0   26.0
# 7       Photo   79.0   18.0
# 8       Photo   79.0   14.0
# 9       Photo   79.0   10.0
# 10      Photo   79.0   20.0
# 11      Photo   79.0   12.0
# 12      Photo   79.0   20.0
# 13      Photo   79.0    8.0
# 14      Photo   79.0   12.0
# 15      Photo   79.0    0.0
# 16      Photo   79.0   24.0
# 17      Photo   79.0   17.0
# 18      Photo   79.0   63.0
# 19      Photo   79.0   22.0
# 20      Photo   79.0   11.0
# 21      Photo   79.0   47.0
# 22      Photo   79.0   23.0
# 23      Photo   79.0   17.0
# 24      Photo   79.0   21.0
# 25      Photo   79.0   17.0
# 26      Photo   79.0    8.0
# 27      Photo   79.0   14.0
# 28      Photo   79.0    3.0
# 29      Photo   79.0   11.0
# ...       ...    ...    ...
# 184004  Video  449.0   76.0
# ...

# %% [markdown]
# Sorting-

# %%
df.sort_values("Type",ascending = True)
# Out:
#      Page_total_likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 438             98195    Link         2           3             6          6
# 470             91437    Link         1           2             3         13
# 41             138895    Link         1          12             6          3
# 43             138353    Link         1          12             5          3
# 45             138353    Link         1          12             4          3
# 47             138353    Link         1          12             3          2
# 49             138353    Link         1          12             2          2
# 430            100732    Link         1           3             7         14
# 425            102112    Link         3           3             1          3
# 86             137177    Link         1          11             4          3
# 408            106928    Link         1           4             6          4
# ...

# %% [markdown]
# Transpose -

# %%
transp_df = df.transpose()
print(transp_df.shape)
transp_df.head()
# Out:
# (19, 500)
#                      0       1       2       3       4       5       6    \
# Page_total_likes  139441  139441  139441  139441  139441  139441  139441
# Type               Photo  Status   Photo   Photo   Photo  Status   Photo
# Category               2       2       3       2       2       2       3
# Post Month            12      12      12      12      12      12      12
# Post Weekday           4       3       3       2       2       1       1
#
#                      7       8       9    ...      490    491    492    493  \
# Page_total_likes  139441  139441  139441  ...    85979  85979  85979  85093
# Type               Photo  Status   Photo  ...    Photo  Photo   Link  Photo
# Category               3       2       3  ...        3      3      1      3
# Post Month            12      12      12  ...        1      1      1      1
# Post Weekday           7       7       6  ...        6      6      5      1
#
# ...

# %% [markdown]
# Melting (wide to long) -

# %%
#df2 = pd.melt(df, id_vars=['Type'],  var_name='metrics', value_name='values')
df2 = pd.melt(df, id_vars=['Type'],  var_name='metrics', value_name='values')
df2
# Out:
#         Type             metrics    values
# 0      Photo    Page_total_likes  139441.0
# 1     Status    Page_total_likes  139441.0
# 2      Photo    Page_total_likes  139441.0
# 3      Photo    Page_total_likes  139441.0
# 4      Photo    Page_total_likes  139441.0
# 5     Status    Page_total_likes  139441.0
# 6      Photo    Page_total_likes  139441.0
# 7      Photo    Page_total_likes  139441.0
# 8     Status    Page_total_likes  139441.0
# 9      Photo    Page_total_likes  139441.0
# 10    Status    Page_total_likes  139441.0
# 11     Photo    Page_total_likes  139441.0
# 12     Photo    Page_total_likes  139441.0
# 13     Photo    Page_total_likes  139441.0
# 14     Photo    Page_total_likes  138414.0
# 15    Status    Page_total_likes  138414.0
# 16     Photo    Page_total_likes  138414.0
# 17     Photo    Page_total_likes  138414.0
# 18    Status    Page_total_likes  138414.0
# 19     Photo    Page_total_likes  138414.0
# 20     Photo    Page_total_likes  138414.0
# ...

# %%
#df3 = df2.pivot(index=["Type"], columns=['metrics'], values='valuess')

# %% [markdown]
# Casting -

# %%
df4 = pd.pivot_table(df2, values = 'values', index=['Type'], columns = 'metrics').reset_index()

# %%
df4
# Out:
# metrics    Type  Category  Lifetime Engaged Users  \
# 0          Link  1.136364              342.818182
# 1         Photo  1.917840              818.946009
# 2        Status  2.022222             2040.222222
# 3         Video  1.000000             1707.000000
#
# metrics  Lifetime People who have liked your Page and engaged with your post  \
# 0                                               210.545455
# 1                                               507.305164
# 2                                              1719.844444
# 3                                               979.428571
#
# metrics  Lifetime Post Consumers  Lifetime Post Consumptions  \
# 0                     292.681818                  374.090909
# 1                     690.431925                 1299.025822
# 2                    1949.555556                 2838.866667
# 3                    1584.714286                 2600.142857
#
# metrics  Lifetime Post Impressions by people who have liked your Page  \
# ...
